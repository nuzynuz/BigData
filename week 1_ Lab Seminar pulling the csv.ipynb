# %%
import pandas as pd

# %%
file = pd.read_csv('MigrationCSV.csv')

# %%
file
# Out:
#         Type                                         SourcePath  \
# 0       File  O:\common3\CSI\No - Nee\NoSeptember2002 09 011...
# 1       File  O:\common3\CSI\No - Nee\NoSeptember2002 09 010...
# 2       File  O:\common3\CSI\No - Nee\NoSeptember2002 09 009...
# 3       File  O:\common3\CSI\No - Nee\NoSeptember2002 09 008...
# 4       File  O:\common3\CSI\No - Nee\NoSeptember2002 09 007...
# ...      ...                                                ...
# 212737  File  H:\ProfilesA\StandeJL\My Documents\A3 prospect...
# 212738  File  H:\ProfilesA\StandeJL\My Documents\360 degree ...
# 212739  File  H:\ProfilesA\StandeJL\My Documents\360 Value e...
# 212740  File      H:\ProfilesA\StandeJL\My Documents\806NOC.pdf
# 212741  File  H:\ProfilesA\StandeJL\My Documents\2007 PPA an...
#
#                                    DestinationSiteAddress  \
# 0       https://sasol.sharepoint.com/sites/TRA-CSI/Les...
# 1       https://sasol.sharepoint.com/sites/TRA-CSI/Les...
# ...

# %%
file.shape
# Out:
# (212742, 6)

# %%
file.info
# Out:
# <bound method DataFrame.info of         Type                                         SourcePath  \
# 0       File  O:\common3\CSI\No - Nee\NoSeptember2002 09 011...
# 1       File  O:\common3\CSI\No - Nee\NoSeptember2002 09 010...
# 2       File  O:\common3\CSI\No - Nee\NoSeptember2002 09 009...
# 3       File  O:\common3\CSI\No - Nee\NoSeptember2002 09 008...
# 4       File  O:\common3\CSI\No - Nee\NoSeptember2002 09 007...
# ...      ...                                                ...
# 212737  File  H:\ProfilesA\StandeJL\My Documents\A3 prospect...
# 212738  File  H:\ProfilesA\StandeJL\My Documents\360 degree ...
# 212739  File  H:\ProfilesA\StandeJL\My Documents\360 Value e...
# 212740  File      H:\ProfilesA\StandeJL\My Documents\806NOC.pdf
# 212741  File  H:\ProfilesA\StandeJL\My Documents\2007 PPA an...
#
#                                    DestinationSiteAddress  \
# 0       https://sasol.sharepoint.com/sites/TRA-CSI/Les...
# ...

# %%
file.describee
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 file.describeribe
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'describeribe'
